# %% [markdown]
# # Find the streak for a team
# Take the last 7 games and calculate the fraction that have been won, lost and drawn.

# %%
import dataset_streak

import csv
import datetime
from functools import reduce


class Dataset:
    def __init__(self, file_path):
        self.raw_results = []
        self.processed_results = []

        with open(file_path) as stream:
            reader = csv.DictReader(stream)

            for row in reader:
                row['Date'] = datetime.datetime.strptime(row['Date'], '%d/%m/%y')
                self.raw_results.append(row)

        for result in self.raw_results:
            home_statistics = self.get_statistics(result['HomeTeam'], result['Date'])

            if home_statistics is None:
                continue

            away_statistics = self.get_statistics(result['AwayTeam'], result['Date'])

            if away_statistics is None:
                continue

            processed_result = {
                'result': result['FTR'],
                'odds-home': float(result['B365H']),
                'odds-draw': float(result['B365D']),
                'odds-away': float(result['B365A']),
            }

            for label, statistics in [('home', home_statistics), ('away', away_statistics)]:
                for key in statistics.keys():
                    processed_result[label + '-' + key] = statistics[key]

            self.processed_results.append(processed_result)

    # Filter results to only contain matches played in by a given team, before a given date
    def filter(self, team, date):
        def filter_fn(result):
            return (
                result['HomeTeam'] == team or
                result['AwayTeam'] == team
            ) and (result['Date'] < date)

        return list(filter(filter_fn, self.raw_results))

    # Calculate team statistics
    def get_statistics(self, team, date, matches=10):
        recent_results = self.filter(team, date)

        if len(recent_results) < matches:
            return None

        # This function maps a result to a set of performance measures roughly scaled between -1 and 1
        def map_fn(result):
            if result['HomeTeam'] == team:
                team_letter, opposition_letter = 'H', 'A'
                opposition = result['AwayTeam']
            else:
                team_letter, opposition_letter = 'A', 'H'
                opposition = result['HomeTeam']

            goals = int(result['FT{}G'.format(team_letter)])
            shots = int(result['{}S'.format(team_letter)])
            shots_on_target = int(result['{}ST'.format(team_letter)])
            shot_accuracy = shots_on_target / shots if shots > 0 else 0

            opposition_goals = int(result['FT{}G'.format(opposition_letter)])
            opposition_shots = int(result['{}S'.format(opposition_letter)])
            opposition_shots_on_target = int(result['{}ST'.format(opposition_letter)])

            return {
                'wins': 1 if result['FTR'] == team_letter else 0,
                'draws': 1 if result['FTR'] == 'D' else 0,
                'losses': 1 if result['FTR'] == opposition_letter else 0,
                'goals': int(result['FT{}G'.format(team_letter)]),
                'opposition-goals': int(result['FT{}G'.format(opposition_letter)]),
                'shots': int(result['{}S'.format(team_letter)]),
                'shots-on-target': int(result['{}ST'.format(team_letter)]),
                'opposition-shots': int(result['{}S'.format(opposition_letter)]),
                'opposition-shots-on-target': int(result['{}ST'.format(opposition_letter)]),
            }

        def reduce_fn(x, y):
            result = {}

            for key in x.keys():
                result[key] = x[key] + y[key]

            return result

        return reduce(reduce_fn, map(map_fn, recent_results[-matches:]))

# %%
data = dataset_streak.Dataset('data/book.csv')

# %%
data.processed_results
# Out:
# [{'result': 'H',
#   'odds-home': 1.17,
#   'odds-draw': 6.5,
#   'odds-away': 21.0,
#   'home-wins': 7,
#   'home-draws': 2,
#   'home-losses': 1,
#   'home-goals': 22,
#   'home-opposition-goals': 4,
#   'home-shots': 178,
#   'home-shots-on-target': 92,
#   'home-opposition-shots': 92,
#   'home-opposition-shots-on-target': 52,
#   'away-wins': 3,
#   'away-draws': 3,
#   'away-losses': 4,
#   'away-goals': 9,
#   'away-opposition-goals': 11,
#   'away-shots': 105,
#   'away-shots-on-target': 52,
#   'away-opposition-shots': 124,
#   'away-opposition-shots-on-target': 81},
#  {'result': 'D',
#   'odds-home': 2.0,
#   'odds-draw': 3.3,
#   'odds-away': 4.0,
#   'home-wins': 4,
#   'home-draws': 1,
#   'home-losses': 5,
#   'home-goals': 10,
#   'home-opposition-goals': 15,
#   'home-shots': 110,
#   'home-shots-on-target': 64,
#   'home-opposition-shots': 151,
#   'home-opposition-shots-on-target': 83,
#   'away-wins': 4,
#   'away-draws': 0,
#   'away-losses': 6,
#   'away-goals': 14,
#   'away-opposition-goals': 18,
#   'away-shots': 116,
#   'away-shots-on-target': 57,
#   'away-opposition-shots': 155,
#   'away-opposition-shots-on-target': 79},
#  {'result': 'A',
#   'odds-home': 1.91,
#   'odds-draw': 3.4,
#   'odds-away': 4.2,
#   'home-wins': 4,
#   'home-draws': 2,
#   'home-losses': 4,
#   'home-goals': 10,
#   'home-opposition-goals': 15,
#   'home-shots': 120,
#   'home-shots-on-target': 68,
#   'home-opposition-shots': 130,
#   'home-opposition-shots-on-target': 69,
#   'away-wins': 2,
#   'away-draws': 2,
#   'away-losses': 6,
#   'away-goals': 11,
#   'away-opposition-goals': 15,
#   'away-shots': 125,
#   'away-shots-on-target': 58,
#   'away-opposition-shots': 99,
#   'away-opposition-shots-on-target': 49},
#  {'result': 'H',
#   'odds-home': 8.0,
#   'odds-draw': 4.5,
#   'odds-away': 1.4,
#   'home-wins': 3,
#   'home-draws': 1,
#   'home-losses': 6,
#   'home-goals': 11,
#   'home-opposition-goals': 18,
#   'home-shots': 76,
#   'home-shots-on-target': 37,
#   'home-opposition-shots': 144,
#   'home-opposition-shots-on-target': 80,
#   'away-wins': 6,
#   'away-draws': 2,
#   'away-losses': 2,
#   'away-goals': 22,
#   'away-opposition-goals': 10,
#   'away-shots': 189,
#   'away-shots-on-target': 105,
#   'away-opposition-shots': 74,
#   'away-opposition-shots-on-target': 41},
#  {'result': 'H',
#   'odds-home': 3.5,
#   'odds-draw': 3.3,
#   'odds-away': 2.1,
#   'home-wins': 1,
#   'home-draws': 3,
#   'home-losses': 6,
#   'home-goals': 11,
#   'home-opposition-goals': 16,
#   'home-shots': 141,
#   'home-shots-on-target': 81,
#   'home-opposition-shots': 124,
#   'home-opposition-shots-on-target': 69,
#   'away-wins': 8,
#   'away-draws': 2,
#   'away-losses': 0,
#   'away-goals': 15,
#   'away-opposition-goals': 6,
#   'away-shots': 152,
#   'away-shots-on-target': 74,
#   'away-opposition-shots': 66,
#   'away-opposition-shots-on-target': 31},
#  {'result': 'D',
#   'odds-home': 2.5,
#   'odds-draw': 3.3,
#   'odds-away': 2.88,
#   'home-wins': 3,
#   'home-draws': 1,
#   'home-losses': 6,
#   'home-goals': 8,
#   'home-opposition-goals': 16,
#   'home-shots': 125,
#   'home-shots-on-target': 68,
#   'home-opposition-shots': 162,
#   'home-opposition-shots-on-target': 95,
#   'away-wins': 3,
#   'away-draws': 3,
#   'away-losses': 4,
#   'away-goals': 11,
#   'away-opposition-goals': 18,
#   'away-shots': 107,
#   'away-shots-on-target': 52,
#   'away-opposition-shots': 101,
#   'away-opposition-shots-on-target': 51},
#  {'result': 'H',
#   'odds-home': 3.0,
#   'odds-draw': 3.3,
#   'odds-away': 2.38,
#   'home-wins': 2,
#   'home-draws': 2,
#   'home-losses': 6,
#   'home-goals': 8,
#   'home-opposition-goals': 13,
#   'home-shots': 121,
#   'home-shots-on-target': 66,
#   'home-opposition-shots': 152,
#   'home-opposition-shots-on-target': 85,
#   'away-wins': 4,
#   'away-draws': 1,
#   'away-losses': 5,
#   'away-goals': 23,
#   'away-opposition-goals': 16,
#   'away-shots': 132,
#   'away-shots-on-target': 81,
#   'away-opposition-shots': 98,
#   'away-opposition-shots-on-target': 48},
#  {'result': 'H',
#   'odds-home': 3.0,
#   'odds-draw': 3.3,
#   'odds-away': 2.38,
#   'home-wins': 2,
#   'home-draws': 3,
#   'home-losses': 5,
#   'home-goals': 12,
#   'home-opposition-goals': 18,
#   'home-shots': 90,
#   'home-shots-on-target': 49,
#   'home-opposition-shots': 137,
#   'home-opposition-shots-on-target': 68,
#   'away-wins': 6,
#   'away-draws': 2,
#   'away-losses': 2,
#   'away-goals': 19,
#   'away-opposition-goals': 12,
#   'away-shots': 98,
#   'away-shots-on-target': 57,
#   'away-opposition-shots': 128,
#   'away-opposition-shots-on-target': 60},
#  {'result': 'H',
#   'odds-home': 3.25,
#   'odds-draw': 3.25,
#   'odds-away': 2.3,
#   'home-wins': 5,
#   'home-draws': 2,
#   'home-losses': 3,
#   'home-goals': 22,
#   'home-opposition-goals': 12,
#   'home-shots': 178,
#   'home-shots-on-target': 97,
#   'home-opposition-shots': 76,
#   'home-opposition-shots-on-target': 42,
#   'away-wins': 6,
#   'away-draws': 3,
#   'away-losses': 1,
#   'away-goals': 19,
#   'away-opposition-goals': 8,
#   'away-shots': 176,
#   'away-shots-on-target': 114,
#   'away-opposition-shots': 110,
#   'away-opposition-shots-on-target': 61},
#  {'result': 'A',
#   'odds-home': 2.25,
#   'odds-draw': 3.25,
#   'odds-away': 3.4,
#   'home-wins': 5,
#   'home-draws': 2,
#   'home-losses': 3,
#   'home-goals': 15,
#   'home-opposition-goals': 17,
#   'home-shots': 100,
#   'home-shots-on-target': 55,
#   'home-opposition-shots': 180,
#   'home-opposition-shots-on-target': 90,
#   'away-wins': 2,
#   'away-draws': 2,
#   'away-losses': 6,
#   'away-goals': 7,
#   'away-opposition-goals': 12,
#   'away-shots': 127,
#   'away-shots-on-target': 70,
#   'away-opposition-shots': 155,
#   'away-opposition-shots-on-target': 89},
#  {'result': 'H',
#   'odds-home': 1.2,
#   'odds-draw': 6.0,
#   'odds-away': 19.0,
#   'home-wins': 7,
#   'home-draws': 2,
#   'home-losses': 1,
#   'home-goals': 15,
#   'home-opposition-goals': 8,
#   'home-shots': 152,
#   'home-shots-on-target': 72,
#   'home-opposition-shots': 68,
#   'home-opposition-shots-on-target': 32,
#   'away-wins': 3,
#   'away-draws': 2,
#   'away-losses': 5,
#   'away-goals': 10,
#   'away-opposition-goals': 17,
#   'away-shots': 135,
#   'away-shots-on-target': 72,
#   'away-opposition-shots': 147,
#   'away-opposition-shots-on-target': 86},
#  {'result': 'A',
#   'odds-home': 2.38,
#   'odds-draw': 3.3,
#   'odds-away': 3.0,
#   'home-wins': 3,
#   'home-draws': 3,
#   'home-losses': 4,
#   'home-goals': 9,
#   'home-opposition-goals': 15,
#   'home-shots': 100,
#   'home-shots-on-target': 49,
#   'home-opposition-shots': 127,
#   'home-opposition-shots-on-target': 84,
#   'away-wins': 4,
#   'away-draws': 2,
#   'away-losses': 4,
#   'away-goals': 11,
#   'away-opposition-goals': 13,
#   'away-shots': 124,
#   'away-shots-on-target': 68,
#   'away-opposition-shots': 124,
#   'away-opposition-shots-on-target': 66},
#  {'result': 'A',
#   'odds-home': 2.6,
#   'odds-draw': 3.25,
#   'odds-away': 2.8,
#   'home-wins': 3,
#   'home-draws': 1,
#   'home-losses': 6,
#   'home-goals': 13,
#   'home-opposition-goals': 18,
#   'home-shots': 114,
#   'home-shots-on-target': 57,
#   'home-opposition-shots': 144,
#   'home-opposition-shots-on-target': 77,
#   'away-wins': 4,
#   'away-draws': 3,
#   'away-losses': 3,
#   'away-goals': 13,
#   'away-opposition-goals': 16,
#   'away-shots': 107,
#   'away-shots-on-target': 57,
#   'away-opposition-shots': 136,
#   'away-opposition-shots-on-target': 81},
#  {'result': 'D',
#   'odds-home': 1.8,
#   'odds-draw': 3.4,
#   'odds-away': 5.0,
#   'home-wins': 3,
#   'home-draws': 2,
#   'home-losses': 5,
#   'home-goals': 12,
#   'home-opposition-goals': 14,
#   'home-shots': 115,
#   'home-shots-on-target': 57,
#   'home-opposition-shots': 100,
#   'home-opposition-shots-on-target': 49,
#   'away-wins': 4,
#   'away-draws': 1,
#   'away-losses': 5,
#   'away-goals': 12,
#   'away-opposition-goals': 16,
#   'away-shots': 75,
#   'away-shots-on-target': 40,
#   'away-opposition-shots': 143,
#   'away-opposition-shots-on-target': 78},
#  {'result': 'A',
#   'odds-home': 1.7,
#   'odds-draw': 3.8,
#   'odds-away': 5.0,
#   'home-wins': 5,
#   'home-draws': 2,
#   'home-losses': 3,
#   'home-goals': 15,
#   'home-opposition-goals': 12,
#   'home-shots': 90,
#   'home-shots-on-target': 48,
#   'home-opposition-shots': 126,
#   'home-opposition-shots-on-target': 59,
#   'away-wins': 3,
#   'away-draws': 2,
#   'away-losses': 5,
#   'away-goals': 9,
#   'away-opposition-goals': 15,
#   'away-shots': 107,
#   'away-shots-on-target': 61,
#   'away-opposition-shots': 156,
#   'away-opposition-shots-on-target': 86},
#  {'result': 'A',
#   'odds-home': 8.0,
#   'odds-draw': 4.33,
#   'odds-away': 1.44,
#   'home-wins': 2,
#   'home-draws': 4,
#   'home-losses': 4,
#   'home-goals': 10,
#   'home-opposition-goals': 18,
#   'home-shots': 101,
#   'home-shots-on-target': 46,
#   'home-opposition-shots': 106,
#   'home-opposition-shots-on-target': 54,
#   'away-wins': 7,
#   'away-draws': 2,
#   'away-losses': 1,
#   'away-goals': 23,
#   'away-opposition-goals': 4,
#   'away-shots': 177,
#   'away-shots-on-target': 92,
#   'away-opposition-shots': 81,
#   'away-opposition-shots-on-target': 44},
#  {'result': 'H',
#   'odds-home': 2.38,
#   'odds-draw': 3.25,
#   'odds-away': 3.1,
#   'home-wins': 3,
#   'home-draws': 2,
#   'home-losses': 5,
#   'home-goals': 8,
#   'home-opposition-goals': 9,
#   'home-shots': 124,
#   'home-shots-on-target': 58,
#   'home-opposition-shots': 123,
#   'home-opposition-shots-on-target': 66,
#   'away-wins': 3,
#   'away-draws': 2,
#   'away-losses': 5,
#   'away-goals': 13,
#   'away-opposition-goals': 17,
#   'away-shots': 90,
#   'away-shots-on-target': 52,
#   'away-opposition-shots': 125,
#   'away-opposition-shots-on-target': 57},
#  {'result': 'A',
#   'odds-home': 2.25,
#   'odds-draw': 3.3,
#   'odds-away': 3.3,
#   'home-wins': 4,
#   'home-draws': 1,
#   'home-losses': 5,
#   'home-goals': 21,
#   'home-opposition-goals': 14,
#   'home-shots': 130,
#   'home-shots-on-target': 79,
#   'home-opposition-shots': 104,
#   'home-opposition-shots-on-target': 50,
#   'away-wins': 2,
#   'away-draws': 3,
#   'away-losses': 5,
#   'away-goals': 12,
#   'away-opposition-goals': 15,
#   'away-shots': 141,
#   'away-shots-on-target': 80,
#   'away-opposition-shots': 124,
#   'away-opposition-shots-on-target': 65},
#  {'result': 'A',
#   'odds-home': 1.5,
#   'odds-draw': 4.0,
#   'odds-away': 7.0,
#   'home-wins': 6,
#   'home-draws': 2,
#   'home-losses': 2,
#   'home-goals': 24,
#   'home-opposition-goals': 12,
#   'home-shots': 174,
#   'home-shots-on-target': 98,
#   'home-opposition-shots': 88,
#   'home-opposition-shots-on-target': 49,
#   'away-wins': 5,
#   'away-draws': 2,
#   'away-losses': 3,
#   'away-goals': 14,
#   'away-opposition-goals': 11,
#   'away-shots': 99,
#   'away-shots-on-target': 55,
#   'away-opposition-shots': 133,
#   'away-opposition-shots-on-target': 65},
#  {'result': 'A',
#   'odds-home': 2.0,
#   'odds-draw': 3.4,
#   'odds-away': 3.8,
#   'home-wins': 2,
#   'home-draws': 3,
#   'home-losses': 5,
#   'home-goals': 9,
#   'home-opposition-goals': 19,
#   'home-shots': 97,
#   'home-shots-on-target': 44,
#   'home-opposition-shots': 117,
#   'home-opposition-shots-on-target': 63,
#   'away-wins': 2,
#   'away-draws': 3,
#   'away-losses': 5,
#   'away-goals': 8,
#   'away-opposition-goals': 16,
#   'away-shots': 97,
#   'away-shots-on-target': 48,
#   'away-opposition-shots': 119,
#   'away-opposition-shots-on-target': 78},
#  {'result': 'A',
#   'odds-home': 6.0,
#   'odds-draw': 3.75,
#   'odds-away': 1.62,
#   'home-wins': 3,
#   'home-draws': 2,
#   'home-losses': 5,
#   'home-goals': 8,
#   'home-opposition-goals': 11,
#   'home-shots': 128,
#   'home-shots-on-target': 72,
#   'home-opposition-shots': 161,
#   'home-opposition-shots-on-target': 92,
#   'away-wins': 7,
#   'away-draws': 2,
#   'away-losses': 1,
#   'away-goals': 16,
#   'away-opposition-goals': 7,
#   'away-shots': 147,
#   'away-shots-on-target': 74,
#   'away-opposition-shots': 63,
#   'away-opposition-shots-on-target': 30},
#  {'result': 'H',
#   'odds-home': 3.3,
#   'odds-draw': 3.3,
#   'odds-away': 2.25,
#   'home-wins': 4,
#   'home-draws': 2,
#   'home-losses': 4,
#   'home-goals': 9,
#   'home-opposition-goals': 8,
#   'home-shots': 123,
#   'home-shots-on-target': 58,
#   'home-opposition-shots': 125,
#   'home-opposition-shots-on-target': 67,
#   'away-wins': 3,
#   'away-draws': 3,
#   'away-losses': 4,
#   'away-goals': 13,
#   'away-opposition-goals': 14,
#   'away-shots': 137,
#   'away-shots-on-target': 78,
#   'away-opposition-shots': 121,
#   'away-opposition-shots-on-target': 65},
#  {'result': 'H',
#   'odds-home': 1.14,
#   'odds-draw': 7.5,
#   'odds-away': 23.0,
#   'home-wins': 6,
#   'home-draws': 2,
#   'home-losses': 2,
#   'home-goals': 19,
#   'home-opposition-goals': 9,
#   'home-shots': 175,
#   'home-shots-on-target': 111,
#   'home-opposition-shots': 110,
#   'home-opposition-shots-on-target': 64,
#   'away-wins': 3,
#   'away-draws': 2,
#   'away-losses': 5,
#   'away-goals': 9,
#   'away-opposition-goals': 14,
#   'away-shots': 69,
#   'away-shots-on-target': 39,
#   'away-opposition-shots': 160,
#   'away-opposition-shots-on-target': 90},
#  {'result': 'D',
#   'odds-home': 2.1,
#   'odds-draw': 3.3,
#   'odds-away': 3.6,
#   'home-wins': 2,
#   'home-draws': 2,
#   'home-losses': 6,
#   'home-goals': 13,
#   'home-opposition-goals': 19,
#   'home-shots': 93,
#   'home-shots-on-target': 51,
#   'home-opposition-shots': 127,
#   'home-opposition-shots-on-target': 59,
#   'away-wins': 3,
#   'away-draws': 3,
#   'away-losses': 4,
#   'away-goals': 12,
#   'away-opposition-goals': 13,
#   'away-shots': 127,
#   'away-shots-on-target': 65,
#   'away-opposition-shots': 95,
#   'away-opposition-shots-on-target': 47},
#  {'result': 'A',
#   'odds-home': 12.0,
#   'odds-draw': 5.0,
#   'odds-away': 1.3,
#   'home-wins': 3,
#   'home-draws': 2,
#   'home-losses': 5,
#   'home-goals': 9,
#   'home-opposition-goals': 18,
#   'home-shots': 125,
#   'home-shots-on-target': 70,
#   'home-opposition-shots': 149,
#   'home-opposition-shots-on-target': 89,
#   'away-wins': 7,
#   'away-draws': 2,
#   'away-losses': 1,
#   'away-goals': 24,
#   'away-opposition-goals': 4,
#   'away-shots': 188,
#   'away-shots-on-target': 102,
#   'away-opposition-shots': 79,
#   'away-opposition-shots-on-target': 41},
#  {'result': 'D',
#   'odds-home': 2.5,
#   'odds-draw': 3.25,
#   'odds-away': 2.88,
#   'home-wins': 3,
#   'home-draws': 1,
#   'home-losses': 6,
#   'home-goals': 14,
#   'home-opposition-goals': 18,
#   'home-shots': 126,
#   'home-shots-on-target': 70,
#   'home-opposition-shots': 142,
#   'home-opposition-shots-on-target': 75,
#   'away-wins': 5,
#   'away-draws': 2,
#   'away-losses': 3,
#   'away-goals': 13,
#   'away-opposition-goals': 13,
#   'away-shots': 121,
#   'away-shots-on-target': 67,
#   'away-opposition-shots': 121,
#   'away-opposition-shots-on-target': 65},
#  {'result': 'D',
#   'odds-home': 1.83,
#   'odds-draw': 3.5,
#   'odds-away': 4.5,
#   'home-wins': 4,
#   'home-draws': 3,
#   'home-losses': 3,
#   'home-goals': 14,
#   'home-opposition-goals': 16,
#   'home-shots': 110,
#   'home-shots-on-target': 57,
#   'home-opposition-shots': 137,
#   'home-opposition-shots-on-target': 90,
#   'away-wins': 4,
#   'away-draws': 2,
#   'away-losses': 4,
#   'away-goals': 10,
#   'away-opposition-goals': 14,
#   'away-shots': 113,
#   'away-shots-on-target': 65,
#   'away-opposition-shots': 154,
#   'away-opposition-shots-on-target': 87},
#  {'result': 'D',
#   'odds-home': 2.88,
#   'odds-draw': 3.25,
#   'odds-away': 2.5,
#   'home-wins': 5,
#   'home-draws': 1,
#   'home-losses': 4,
#   'home-goals': 14,
#   'home-opposition-goals': 17,
#   'home-shots': 109,
#   'home-shots-on-target': 62,
#   'home-opposition-shots': 178,
#   'home-opposition-shots-on-target': 91,
#   'away-wins': 3,
#   'away-draws': 1,
#   'away-losses': 6,
#   'away-goals': 19,
#   'away-opposition-goals': 16,
#   'away-shots': 125,
#   'away-shots-on-target': 77,
#   'away-opposition-shots': 115,
#   'away-opposition-shots-on-target': 59},
#  {'result': 'D',
#   'odds-home': 5.0,
#   'odds-draw': 3.6,
#   'odds-away': 1.73,
#   'home-wins': 6,
#   'home-draws': 1,
#   'home-losses': 3,
#   'home-goals': 16,
#   'home-opposition-goals': 11,
#   'home-shots': 103,
#   'home-shots-on-target': 59,
#   'home-opposition-shots': 136,
#   'home-opposition-shots-on-target': 70,
#   'away-wins': 6,
#   'away-draws': 2,
#   'away-losses': 2,
#   'away-goals': 23,
#   'away-opposition-goals': 9,
#   'away-shots': 184,
#   'away-shots-on-target': 119,
#   'away-opposition-shots': 100,
#   'away-opposition-shots-on-target': 59},
#  {'result': 'D',
#   'odds-home': 1.2,
#   'odds-draw': 6.0,
#   'odds-away': 19.0,
#   'home-wins': 8,
#   'home-draws': 1,
#   'home-losses': 1,
#   'home-goals': 26,
#   'home-opposition-goals': 3,
#   'home-shots': 191,
#   'home-shots-on-target': 108,
#   'home-opposition-shots': 86,
#   'home-opposition-shots-on-target': 38,
#   'away-wins': 2,
#   'away-draws': 3,
#   'away-losses': 5,
#   'away-goals': 15,
#   'away-opposition-goals': 18,
#   'away-shots': 106,
#   'away-shots-on-target': 58,
#   'away-opposition-shots': 119,
#   'away-opposition-shots-on-target': 52},
#  {'result': 'D',
#   'odds-home': 1.25,
#   'odds-draw': 5.5,
#   'odds-away': 15.0,
#   'home-wins': 8,
#   'home-draws': 1,
#   'home-losses': 1,
#   'home-goals': 18,
#   'home-opposition-goals': 7,
#   'home-shots': 154,
#   'home-shots-on-target': 77,
#   'home-opposition-shots': 73,
#   'home-opposition-shots-on-target': 37,
#   'away-wins': 4,
#   'away-draws': 2,
#   'away-losses': 4,
#   'away-goals': 10,
#   'away-opposition-goals': 9,
#   'away-shots': 134,
#   'away-shots-on-target': 70,
#   'away-opposition-shots': 117,
#   'away-opposition-shots-on-target': 64},
#  {'result': 'H',
#   'odds-home': 3.25,
#   'odds-draw': 3.4,
#   'odds-away': 2.2,
#   'home-wins': 2,
#   'home-draws': 2,
#   'home-losses': 6,
#   'home-goals': 18,
#   'home-opposition-goals': 18,
#   'home-shots': 128,
#   'home-shots-on-target': 77,
#   'home-opposition-shots': 116,
#   'home-opposition-shots-on-target': 61,
#   'away-wins': 5,
#   'away-draws': 2,
#   'away-losses': 3,
#   'away-goals': 21,
#   'away-opposition-goals': 14,
#   'away-shots': 165,
#   'away-shots-on-target': 92,
#   'away-opposition-shots': 93,
#   'away-opposition-shots-on-target': 53},
#  {'result': 'A',
#   'odds-home': 1.91,
#   'odds-draw': 3.4,
#   'odds-away': 4.33,
#   'home-wins': 3,
#   'home-draws': 3,
#   'home-losses': 4,
#   'home-goals': 9,
#   'home-opposition-goals': 14,
#   'home-shots': 103,
#   'home-shots-on-target': 56,
#   'home-opposition-shots': 162,
#   'home-opposition-shots-on-target': 92,
#   'away-wins': 3,
#   'away-draws': 1,
#   'away-losses': 6,
#   'away-goals': 8,
#   'away-opposition-goals': 13,
#   'away-shots': 125,
#   'away-shots-on-target': 72,
#   'away-opposition-shots': 164,
#   'away-opposition-shots-on-target': 91},
#  {'result': 'D',
#   'odds-home': 1.8,
#   'odds-draw': 3.6,
#   'odds-away': 4.5,
#   'home-wins': 4,
#   'home-draws': 3,
#   'home-losses': 3,
#   'home-goals': 10,
#   'home-opposition-goals': 13,
#   'home-shots': 126,
#   'home-shots-on-target': 69,
#   'home-opposition-shots': 116,
#   'home-opposition-shots-on-target': 63,
#   'away-wins': 5,
#   'away-draws': 2,
#   'away-losses': 3,
#   'away-goals': 16,
#   'away-opposition-goals': 14,
#   'away-shots': 110,
#   'away-shots-on-target': 63,
#   'away-opposition-shots': 182,
#   'away-opposition-shots-on-target': 94},
#  {'result': 'H',
#   'odds-home': 2.2,
#   'odds-draw': 3.3,
#   'odds-away': 3.4,
#   'home-wins': 3,
#   'home-draws': 2,
#   'home-losses': 5,
#   'home-goals': 8,
#   'home-opposition-goals': 17,
#   'home-shots': 65,
#   'home-shots-on-target': 38,
#   'home-opposition-shots': 160,
#   'home-opposition-shots-on-target': 93,
#   'away-wins': 3,
#   'away-draws': 1,
#   'away-losses': 6,
#   'away-goals': 9,
#   'away-opposition-goals': 21,
#   'away-shots': 126,
#   'away-shots-on-target': 66,
#   'away-opposition-shots': 146,
#   'away-opposition-shots-on-target': 89},
#  {'result': 'A',
#   'odds-home': 2.1,
#   'odds-draw': 3.4,
#   'odds-away': 3.5,
#   'home-wins': 3,
#   'home-draws': 3,
#   'home-losses': 4,
#   'home-goals': 10,
#   'home-opposition-goals': 14,
#   'home-shots': 97,
#   'home-shots-on-target': 50,
#   'home-opposition-shots': 126,
#   'home-opposition-shots-on-target': 78,
#   'away-wins': 2,
#   'away-draws': 2,
#   'away-losses': 6,
#   'away-goals': 10,
#   'away-opposition-goals': 17,
#   'away-shots': 126,
#   'away-shots-on-target': 69,
#   'away-opposition-shots': 141,
#   'away-opposition-shots-on-target': 75},
#  {'result': 'H',
#   'odds-home': 1.73,
#   'odds-draw': 3.75,
#   'odds-away': 4.75,
#   'home-wins': 3,
#   'home-draws': 2,
#   'home-losses': 5,
#   'home-goals': 13,
#   'home-opposition-goals': 15,
#   'home-shots': 138,
#   'home-shots-on-target': 75,
#   'home-opposition-shots': 125,
#   'home-opposition-shots-on-target': 76,
#   'away-wins': 2,
#   'away-draws': 3,
#   'away-losses': 5,
#   'away-goals': 9,
#   'away-opposition-goals': 17,
#   'away-shots': 101,
#   'away-shots-on-target': 45,
#   'away-opposition-shots': 116,
#   'away-opposition-shots-on-target': 63},
#  {'result': 'H',
#   'odds-home': 2.5,
#   'odds-draw': 3.3,
#   'odds-away': 2.88,
#   'home-wins': 2,
#   'home-draws': 4,
#   'home-losses': 4,
#   'home-goals': 9,
#   'home-opposition-goals': 15,
#   'home-shots': 131,
#   'home-shots-on-target': 67,
#   'home-opposition-shots': 102,
#   'home-opposition-shots-on-target': 51,
#   'away-wins': 4,
#   'away-draws': 4,
#   'away-losses': 2,
#   'away-goals': 15,
#   'away-opposition-goals': 14,
#   'away-shots': 109,
#   'away-shots-on-target': 57,
#   'away-opposition-shots': 142,
#   'away-opposition-shots-on-target': 88},
#  {'result': 'D',
#   'odds-home': 1.57,
#   'odds-draw': 3.8,
#   'odds-away': 6.5,
#   'home-wins': 5,
#   'home-draws': 2,
#   'home-losses': 3,
#   'home-goals': 14,
#   'home-opposition-goals': 10,
#   'home-shots': 96,
#   'home-shots-on-target': 53,
#   'home-opposition-shots': 131,
#   'home-opposition-shots-on-target': 67,
#   'away-wins': 3,
#   'away-draws': 3,
#   'away-losses': 4,
#   'away-goals': 8,
#   'away-opposition-goals': 8,
#   'away-shots': 120,
#   'away-shots-on-target': 63,
#   'away-opposition-shots': 127,
#   'away-opposition-shots-on-target': 64},
#  {'result': 'D',
#   'odds-home': 2.2,
#   'odds-draw': 3.3,
#   'odds-away': 3.4,
#   'home-wins': 3,
#   'home-draws': 3,
#   'home-losses': 4,
#   'home-goals': 9,
#   'home-opposition-goals': 15,
#   'home-shots': 114,
#   'home-shots-on-target': 58,
#   'home-opposition-shots': 152,
#   'home-opposition-shots-on-target': 85,
#   'away-wins': 2,
#   'away-draws': 4,
#   'away-losses': 4,
#   'away-goals': 14,
#   'away-opposition-goals': 16,
#   'away-shots': 95,
#   'away-shots-on-target': 54,
#   'away-opposition-shots': 136,
#   'away-opposition-shots-on-target': 62},
#  {'result': 'D',
#   'odds-home': 2.4,
#   'odds-draw': 3.4,
#   'odds-away': 2.88,
#   'home-wins': 4,
#   'home-draws': 2,
#   'home-losses': 4,
#   'home-goals': 7,
#   'home-opposition-goals': 14,
#   'home-shots': 62,
#   'home-shots-on-target': 38,
#   'home-opposition-shots': 160,
#   'home-opposition-shots-on-target': 90,
#   'away-wins': 4,
#   'away-draws': 3,
#   'away-losses': 3,
#   'away-goals': 16,
#   'away-opposition-goals': 15,
#   'away-shots': 115,
#   'away-shots-on-target': 65,
#   'away-opposition-shots': 183,
#   'away-opposition-shots-on-target': 97},
#  {'result': 'A',
#   'odds-home': 2.25,
#   'odds-draw': 3.3,
#   'odds-away': 3.3,
#   'home-wins': 3,
#   'home-draws': 2,
#   'home-losses': 5,
#   'home-goals': 9,
#   'home-opposition-goals': 14,
#   'home-shots': 108,
#   'home-shots-on-target': 51,
#   'home-opposition-shots': 124,
#   'home-opposition-shots-on-target': 75,
#   'away-wins': 4,
#   'away-draws': 1,
#   'away-losses': 5,
#   'away-goals': 10,
#   'away-opposition-goals': 12,
#   'away-shots': 128,
#   'away-shots-on-target': 70,
#   'away-opposition-shots': 162,
#   'away-opposition-shots-on-target': 83},
#  {'result': 'H',
#   'odds-home': 1.73,
#   'odds-draw': 3.6,
#   'odds-away': 5.0,
#   'home-wins': 3,
#   'home-draws': 3,
#   'home-losses': 4,
#   'home-goals': 9,
#   'home-opposition-goals': 14,
#   'home-shots': 131,
#   'home-shots-on-target': 65,
#   'home-opposition-shots': 103,
#   'home-opposition-shots-on-target': 48,
#   'away-wins': 2,
#   'away-draws': 1,
#   'away-losses': 7,
#   'away-goals': 6,
#   'away-opposition-goals': 20,
#   'away-shots': 121,
#   'away-shots-on-target': 60,
#   'away-opposition-shots': 134,
#   'away-opposition-shots-on-target': 83},
#  {'result': 'A',
#   'odds-home': 1.8,
#   'odds-draw': 3.4,
#   'odds-away': 5.0,
#   'home-wins': 7,
#   'home-draws': 2,
#   'home-losses': 1,
#   'home-goals': 23,
#   'home-opposition-goals': 2,
#   'home-shots': 198,
#   'home-shots-on-target': 114,
#   'home-opposition-shots': 75,
#   'home-opposition-shots-on-target': 31,
#   'away-wins': 4,
#   'away-draws': 2,
#   'away-losses': 4,
#   'away-goals': 17,
#   'away-opposition-goals': 17,
#   'away-shots': 159,
#   'away-shots-on-target': 87,
#   'away-opposition-shots': 95,
#   'away-opposition-shots-on-target': 58},
#  {'result': 'A',
#   'odds-home': 4.33,
#   'odds-draw': 3.6,
#   'odds-away': 1.83,
#   'home-wins': 3,
#   'home-draws': 2,
#   'home-losses': 5,
#   'home-goals': 20,
#   'home-opposition-goals': 15,
#   'home-shots': 127,
#   'home-shots-on-target': 78,
#   'home-opposition-shots': 109,
#   'home-opposition-shots-on-target': 58,
#   'away-wins': 6,
#   'away-draws': 3,
#   'away-losses': 1,
#   'away-goals': 22,
#   'away-opposition-goals': 7,
#   'away-shots': 189,
#   'away-shots-on-target': 123,
#   'away-opposition-shots': 94,
#   'away-opposition-shots-on-target': 55},
#  {'result': 'H',
#   'odds-home': 2.1,
#   'odds-draw': 3.3,
#   'odds-away': 3.6,
#   'home-wins': 3,
#   'home-draws': 4,
#   'home-losses': 3,
#   'home-goals': 10,
#   'home-opposition-goals': 14,
#   'home-shots': 119,
#   'home-shots-on-target': 64,
#   'home-opposition-shots': 122,
#   'home-opposition-shots-on-target': 66,
#   'away-wins': 2,
#   'away-draws': 3,
#   'away-losses': 5,
#   'away-goals': 9,
#   'away-opposition-goals': 14,
#   'away-shots': 100,
#   'away-shots-on-target': 48,
#   'away-opposition-shots': 115,
#   'away-opposition-shots-on-target': 60},
#  {'result': 'A',
#   'odds-home': 1.91,
#   'odds-draw': 3.5,
#   'odds-away': 4.0,
#   'home-wins': 4,
#   'home-draws': 2,
#   'home-losses': 4,
#   'home-goals': 13,
#   'home-opposition-goals': 13,
#   'home-shots': 137,
#   'home-shots-on-target': 72,
#   'home-opposition-shots': 117,
#   'home-opposition-shots-on-target': 69,
#   'away-wins': 3,
#   'away-draws': 4,
#   'away-losses': 3,
#   'away-goals': 12,
#   'away-opposition-goals': 13,
#   'away-shots': 108,
#   'away-shots-on-target': 54,
#   'away-opposition-shots': 142,
#   'away-opposition-shots-on-target': 87},
#  {'result': 'D',
#   'odds-home': 1.3,
#   'odds-draw': 5.0,
#   'odds-away': 12.0,
#   'home-wins': 7,
#   'home-draws': 2,
#   'home-losses': 1,
#   'home-goals': 16,
#   'home-opposition-goals': 6,
#   'home-shots': 156,
#   'home-shots-on-target': 73,
#   'home-opposition-shots': 72,
#   'home-opposition-shots-on-target': 40,
#   'away-wins': 3,
#   'away-draws': 2,
#   'away-losses': 5,
#   'away-goals': 9,
#   'away-opposition-goals': 14,
#   'away-shots': 115,
#   'away-shots-on-target': 61,
#   'away-opposition-shots': 145,
#   'away-opposition-shots-on-target': 73},
#  {'result': 'H',
#   'odds-home': 1.33,
#   'odds-draw': 4.75,
#   'odds-away': 11.0,
#   'home-wins': 4,
#   'home-draws': 2,
#   'home-losses': 4,
#   'home-goals': 16,
#   'home-opposition-goals': 17,
#   'home-shots': 148,
#   'home-shots-on-target': 84,
#   'home-opposition-shots': 95,
#   'home-opposition-shots-on-target': 55,
#   'away-wins': 4,
#   'away-draws': 2,
#   'away-losses': 4,
#   'away-goals': 11,
#   'away-opposition-goals': 15,
#   'away-shots': 134,
#   'away-shots-on-target': 68,
#   'away-opposition-shots': 109,
#   'away-opposition-shots-on-target': 53},
#  {'result': 'A',
#   'odds-home': 5.5,
#   'odds-draw': 3.5,
#   'odds-away': 1.73,
#   'home-wins': 1,
#   'home-draws': 3,
#   'home-losses': 6,
#   'home-goals': 10,
#   'home-opposition-goals': 17,
#   'home-shots': 99,
#   'home-shots-on-target': 46,
#   'home-opposition-shots': 113,
#   'home-opposition-shots-on-target': 61,
#   'away-wins': 7,
#   'away-draws': 2,
#   'away-losses': 1,
#   'away-goals': 16,
#   'away-opposition-goals': 6,
#   'away-shots': 150,
#   'away-shots-on-target': 70,
#   'away-opposition-shots': 76,
#   'away-opposition-shots-on-target': 41},
#  {'result': 'A',
#   'odds-home': 7.0,
#   'odds-draw': 3.8,
#   'odds-away': 1.53,
#   'home-wins': 5,
#   'home-draws': 1,
#   'home-losses': 4,
#   'home-goals': 13,
#   'home-opposition-goals': 10,
#   'home-shots': 127,
#   'home-shots-on-target': 68,
#   'home-opposition-shots': 156,
#   'home-opposition-shots-on-target': 83,
#   'away-wins': 7,
#   'away-draws': 1,
#   'away-losses': 2,
#   'away-goals': 23,
#   'away-opposition-goals': 3,
#   'away-shots': 190,
#   'away-shots-on-target': 106,
#   'away-opposition-shots': 71,
#   'away-opposition-shots-on-target': 29},
#  {'result': 'D',
#   'odds-home': 2.6,
#   'odds-draw': 3.2,
#   'odds-away': 2.8,
#   'home-wins': 3,
#   'home-draws': 4,
#   'home-losses': 3,
#   'home-goals': 8,
#   'home-opposition-goals': 7,
#   'home-shots': 114,
#   'home-shots-on-target': 60,
#   'home-opposition-shots': 128,
#   'home-opposition-shots-on-target': 64,
#   'away-wins': 2,
#   'away-draws': 2,
#   'away-losses': 6,
#   'away-goals': 14,
#   'away-opposition-goals': 16,
#   'away-shots': 123,
#   'away-shots-on-target': 69,
#   'away-opposition-shots': 111,
#   'away-opposition-shots-on-target': 62},
#  {'result': 'H',
#   'odds-home': 2.38,
#   'odds-draw': 3.25,
#   'odds-away': 3.1,
#   'home-wins': 4,
#   'home-draws': 3,
#   'home-losses': 3,
#   'home-goals': 15,
#   'home-opposition-goals': 14,
#   'home-shots': 112,
#   'home-shots-on-target': 65,
#   'home-opposition-shots': 176,
#   'home-opposition-shots-on-target': 94,
#   'away-wins': 3,
#   'away-draws': 4,
#   'away-losses': 3,
#   'away-goals': 9,
#   'away-opposition-goals': 13,
#   'away-shots': 114,
#   'away-shots-on-target': 54,
#   'away-opposition-shots': 145,
#   'away-opposition-shots-on-target': 79},
#  {'result': 'H',
#   'odds-home': 1.14,
#   'odds-draw': 7.5,
#   'odds-away': 23.0,
#   'home-wins': 7,
#   'home-draws': 2,
#   'home-losses': 1,
#   'home-goals': 22,
#   'home-opposition-goals': 6,
#   'home-shots': 188,
#   'home-shots-on-target': 123,
#   'home-opposition-shots': 84,
#   'home-opposition-shots-on-target': 43,
#   'away-wins': 2,
#   'away-draws': 2,
#   'away-losses': 6,
#   'away-goals': 8,
#   'away-opposition-goals': 18,
#   'away-shots': 105,
#   'away-shots-on-target': 49,
#   'away-opposition-shots': 121,
#   'away-opposition-shots-on-target': 70},
#  {'result': 'D',
#   'odds-home': 1.8,
#   'odds-draw': 3.5,
#   'odds-away': 4.75,
#   'home-wins': 2,
#   'home-draws': 5,
#   'home-losses': 3,
#   'home-goals': 13,
#   'home-opposition-goals': 13,
#   'home-shots': 94,
#   'home-shots-on-target': 51,
#   'home-opposition-shots': 138,
#   'home-opposition-shots-on-target': 63,
#   'away-wins': 4,
#   'away-draws': 2,
#   'away-losses': 4,
#   'away-goals': 8,
#   'away-opposition-goals': 15,
#   'away-shots': 69,
#   'away-shots-on-target': 41,
#   'away-opposition-shots': 139,
#   'away-opposition-shots-on-target': 84},
#  {'result': 'A',
#   'odds-home': 2.62,
#   'odds-draw': 3.25,
#   'odds-away': 2.75,
#   'home-wins': 4,
#   'home-draws': 3,
#   'home-losses': 3,
#   'home-goals': 11,
#   'home-opposition-goals': 11,
#   'home-shots': 99,
#   'home-shots-on-target': 52,
#   'home-opposition-shots': 147,
#   'home-opposition-shots-on-target': 88,
#   'away-wins': 4,
#   'away-draws': 3,
#   'away-losses': 3,
#   'away-goals': 12,
#   'away-opposition-goals': 9,
#   'away-shots': 98,
#   'away-shots-on-target': 52,
#   'away-opposition-shots': 126,
#   'away-opposition-shots-on-target': 63},
#  {'result': 'D',
#   'odds-home': 2.62,
#   'odds-draw': 3.25,
#   'odds-away': 2.75,
#   'home-wins': 2,
#   'home-draws': 1,
#   'home-losses': 7,
#   'home-goals': 6,
#   'home-opposition-goals': 20,
#   'home-shots': 128,
#   'home-shots-on-target': 63,
#   'home-opposition-shots': 141,
#   'home-opposition-shots-on-target': 87,
#   'away-wins': 4,
#   'away-draws': 4,
#   'away-losses': 2,
#   'away-goals': 13,
#   'away-opposition-goals': 10,
#   'away-shots': 118,
#   'away-shots-on-target': 66,
#   'away-opposition-shots': 118,
#   'away-opposition-shots-on-target': 58},
#  {'result': 'A',
#   'odds-home': 2.75,
#   'odds-draw': 3.25,
#   'odds-away': 2.62,
#   'home-wins': 2,
#   'home-draws': 3,
#   'home-losses': 5,
#   'home-goals': 6,
#   'home-opposition-goals': 13,
#   'home-shots': 110,
#   'home-shots-on-target': 58,
#   'home-opposition-shots': 155,
#   'home-opposition-shots-on-target': 73,
#   'away-wins': 4,
#   'away-draws': 1,
#   'away-losses': 5,
#   'away-goals': 13,
#   'away-opposition-goals': 14,
#   'away-shots': 140,
#   'away-shots-on-target': 74,
#   'away-opposition-shots': 111,
#   'away-opposition-shots-on-target': 69},
#  {'result': 'H',
#   'odds-home': 1.67,
#   'odds-draw': 3.6,
#   'odds-away': 5.5,
#   'home-wins': 4,
#   'home-draws': 3,
#   'home-losses': 3,
#   'home-goals': 13,
#   'home-opposition-goals': 10,
#   'home-shots': 91,
#   'home-shots-on-target': 49,
#   'home-opposition-shots': 129,
#   'home-opposition-shots-on-target': 67,
#   'away-wins': 5,
#   'away-draws': 1,
#   'away-losses': 4,
#   'away-goals': 13,
#   'away-opposition-goals': 10,
#   'away-shots': 138,
#   'away-shots-on-target': 74,
#   'away-opposition-shots': 136,
#   'away-opposition-shots-on-target': 66},
#  {'result': 'D',
#   'odds-home': 1.33,
#   'odds-draw': 5.0,
#   'odds-away': 10.0,
#   'home-wins': 7,
#   'home-draws': 2,
#   'home-losses': 1,
#   'home-goals': 17,
#   'home-opposition-goals': 7,
#   'home-shots': 149,
#   'home-shots-on-target': 70,
#   'home-opposition-shots': 79,
#   'home-opposition-shots-on-target': 42,
#   'away-wins': 4,
#   'away-draws': 3,
#   'away-losses': 3,
#   'away-goals': 15,
#   'away-opposition-goals': 14,
#   'away-shots': 122,
#   'away-shots-on-target': 67,
#   'away-opposition-shots': 167,
#   'away-opposition-shots-on-target': 92},
#  {'result': 'A',
#   'odds-home': 2.0,
#   'odds-draw': 3.4,
#   'odds-away': 3.8,
#   'home-wins': 2,
#   'home-draws': 3,
#   'home-losses': 5,
#   'home-goals': 14,
#   'home-opposition-goals': 15,
#   'home-shots': 127,
#   'home-shots-on-target': 70,
#   'home-opposition-shots': 114,
#   'home-opposition-shots-on-target': 66,
#   'away-wins': 4,
#   'away-draws': 3,
#   'away-losses': 3,
#   'away-goals': 13,
#   'away-opposition-goals': 12,
#   'away-shots': 107,
#   'away-shots-on-target': 57,
#   'away-opposition-shots': 141,
#   'away-opposition-shots-on-target': 87},
#  {'result': 'D',
#   'odds-home': 4.5,
#   'odds-draw': 3.6,
#   'odds-away': 1.8,
#   'home-wins': 3,
#   'home-draws': 4,
#   'home-losses': 3,
#   'home-goals': 10,
#   'home-opposition-goals': 14,
#   'home-shots': 101,
#   'home-shots-on-target': 48,
#   'home-opposition-shots': 148,
#   'home-opposition-shots-on-target': 77,
#   'away-wins': 5,
#   'away-draws': 2,
#   'away-losses': 3,
#   'away-goals': 16,
#   'away-opposition-goals': 15,
#   'away-shots': 141,
#   'away-shots-on-target': 79,
#   'away-opposition-shots': 98,
#   'away-opposition-shots-on-target': 54},
#  {'result': 'D',
#   'odds-home': 2.5,
#   'odds-draw': 3.25,
#   'odds-away': 2.88,
#   'home-wins': 4,
#   'home-draws': 3,
#   'home-losses': 3,
#   'home-goals': 10,
#   'home-opposition-goals': 15,
#   'home-shots': 76,
#   'home-shots-on-target': 43,
#   'home-opposition-shots': 134,
#   'home-opposition-shots-on-target': 81,
#   'away-wins': 3,
#   'away-draws': 5,
#   'away-losses': 2,
#   'away-goals': 8,
#   'away-opposition-goals': 6,
#   'away-shots': 108,
#   'away-shots-on-target': 62,
#   'away-opposition-shots': 127,
#   'away-opposition-shots-on-target': 61},
#  {'result': 'H',
#   'odds-home': 2.0,
#   'odds-draw': 3.4,
#   'odds-away': 3.8,
#   'home-wins': 2,
#   'home-draws': 2,
#   'home-losses': 6,
#   'home-goals': 7,
#   'home-opposition-goals': 17,
#   'home-shots': 98,
#   'home-shots-on-target': 48,
#   'home-opposition-shots': 136,
#   'home-opposition-shots-on-target': 77,
#   'away-wins': 1,
#   'away-draws': 2,
#   'away-losses': 7,
#   'away-goals': 6,
#   'away-opposition-goals': 21,
#   'away-shots': 128,
#   'away-shots-on-target': 62,
#   'away-opposition-shots': 125,
#   'away-opposition-shots-on-target': 77},
#  {'result': 'D',
#   'odds-home': 4.5,
#   'odds-draw': 3.5,
#   'odds-away': 1.83,
#   'home-wins': 5,
#   'home-draws': 1,
#   'home-losses': 4,
#   'home-goals': 15,
#   'home-opposition-goals': 12,
#   'home-shots': 142,
#   'home-shots-on-target': 78,
#   'home-opposition-shots': 114,
#   'home-opposition-shots-on-target': 67,
#   'away-wins': 7,
#   'away-draws': 2,
#   'away-losses': 1,
#   'away-goals': 21,
#   'away-opposition-goals': 6,
#   'away-shots': 184,
#   'away-shots-on-target': 114,
#   'away-opposition-shots': 76,
#   'away-opposition-shots-on-target': 40},
#  {'result': 'H',
#   'odds-home': 2.1,
#   'odds-draw': 3.3,
#   'odds-away': 3.6,
#   'home-wins': 3,
#   'home-draws': 2,
#   'home-losses': 5,
#   'home-goals': 9,
#   'home-opposition-goals': 15,
#   'home-shots': 135,
#   'home-shots-on-target': 68,
#   'home-opposition-shots': 109,
#   'home-opposition-shots-on-target': 51,
#   'away-wins': 0,
#   'away-draws': 3,
#   'away-losses': 7,
#   'away-goals': 9,
#   'away-opposition-goals': 19,
#   'away-shots': 97,
#   'away-shots-on-target': 41,
#   'away-opposition-shots': 119,
#   'away-opposition-shots-on-target': 65},
#  {'result': 'D',
#   'odds-home': 1.25,
#   'odds-draw': 5.5,
#   'odds-away': 15.0,
#   'home-wins': 7,
#   'home-draws': 1,
#   'home-losses': 2,
#   'home-goals': 23,
#   'home-opposition-goals': 3,
#   'home-shots': 187,
#   'home-shots-on-target': 104,
#   'home-opposition-shots': 87,
#   'home-opposition-shots-on-target': 38,
#   'away-wins': 1,
#   'away-draws': 3,
#   'away-losses': 6,
#   'away-goals': 4,
#   'away-opposition-goals': 14,
#   'away-shots': 105,
#   'away-shots-on-target': 52,
#   'away-opposition-shots': 154,
#   'away-opposition-shots-on-target': 79},
#  {'result': 'A',
#   'odds-home': 2.05,
#   'odds-draw': 3.2,
#   'odds-away': 3.4,
#   'home-wins': 3,
#   'home-draws': 5,
#   'home-losses': 2,
#   'home-goals': 12,
#   'home-opposition-goals': 11,
#   'home-shots': 116,
#   'home-shots-on-target': 63,
#   'home-opposition-shots': 117,
#   'home-opposition-shots-on-target': 58,
#   'away-wins': 2,
#   'away-draws': 6,
#   'away-losses': 2,
#   'away-goals': 14,
#   'away-opposition-goals': 13,
#   'away-shots': 99,
#   'away-shots-on-target': 55,
#   'away-opposition-shots': 141,
#   'away-opposition-shots-on-target': 59},
#  {'result': 'H',
#   'odds-home': 1.83,
#   'odds-draw': 3.5,
#   'odds-away': 4.5,
#   'home-wins': 0,
#   'home-draws': 3,
#   'home-losses': 7,
#   'home-goals': 9,
#   'home-opposition-goals': 20,
#   'home-shots': 102,
#   'home-shots-on-target': 42,
#   'home-opposition-shots': 111,
#   'home-opposition-shots-on-target': 61,
#   'away-wins': 4,
#   'away-draws': 4,
#   'away-losses': 2,
#   'away-goals': 9,
#   'away-opposition-goals': 13,
#   'away-shots': 74,
#   'away-shots-on-target': 40,
#   'away-opposition-shots': 126,
#   'away-opposition-shots-on-target': 76},
#  {'result': 'H',
#   'odds-home': 2.2,
#   'odds-draw': 3.25,
#   'odds-away': 3.4,
#   'home-wins': 4,
#   'home-draws': 1,
#   'home-losses': 5,
#   'home-goals': 12,
#   'home-opposition-goals': 13,
#   'home-shots': 135,
#   'home-shots-on-target': 73,
#   'home-opposition-shots': 139,
#   'home-opposition-shots-on-target': 68,
#   'away-wins': 2,
#   'away-draws': 5,
#   'away-losses': 3,
#   'away-goals': 10,
#   'away-opposition-goals': 13,
#   'away-shots': 117,
#   'away-shots-on-target': 58,
#   'away-opposition-shots': 119,
#   'away-opposition-shots-on-target': 58},
#  {'result': 'H',
#   'odds-home': 2.2,
#   'odds-draw': 3.25,
#   'odds-away': 3.5,
#   'home-wins': 3,
#   'home-draws': 6,
#   'home-losses': 1,
#   'home-goals': 8,
#   'home-opposition-goals': 5,
#   'home-shots': 103,
#   'home-shots-on-target': 63,
#   'home-opposition-shots': 120,
#   'home-opposition-shots-on-target': 55,
#   'away-wins': 2,
#   'away-draws': 5,
#   'away-losses': 3,
#   'away-goals': 10,
#   'away-opposition-goals': 15,
#   'away-shots': 103,
#   'away-shots-on-target': 49,
#   'away-opposition-shots': 144,
#   'away-opposition-shots-on-target': 79},
#  {'result': 'A',
#   'odds-home': 2.1,
#   'odds-draw': 3.25,
#   'odds-away': 3.75,
#   'home-wins': 3,
#   'home-draws': 4,
#   'home-losses': 3,
#   'home-goals': 16,
#   'home-opposition-goals': 16,
#   'home-shots': 121,
#   'home-shots-on-target': 64,
#   'home-opposition-shots': 162,
#   'home-opposition-shots-on-target': 86,
#   'away-wins': 3,
#   'away-draws': 1,
#   'away-losses': 6,
#   'away-goals': 10,
#   'away-opposition-goals': 16,
#   'away-shots': 106,
#   'away-shots-on-target': 53,
#   'away-opposition-shots': 137,
#   'away-opposition-shots-on-target': 76},
#  {'result': 'A',
#   'odds-home': 3.0,
#   'odds-draw': 3.4,
#   'odds-away': 2.37,
#   'home-wins': 1,
#   'home-draws': 4,
#   'home-losses': 5,
#   'home-goals': 4,
#   'home-opposition-goals': 12,
#   'home-shots': 96,
#   'home-shots-on-target': 49,
#   'home-opposition-shots': 161,
#   'home-opposition-shots-on-target': 85,
#   'away-wins': 5,
#   'away-draws': 3,
#   'away-losses': 2,
#   'away-goals': 17,
#   'away-opposition-goals': 10,
#   'away-shots': 99,
#   'away-shots-on-target': 53,
#   'away-opposition-shots': 111,
#   'away-opposition-shots-on-target': 57},
#  {'result': 'D',
#   'odds-home': 2.4,
#   'odds-draw': 3.25,
#   'odds-away': 3.0,
#   'home-wins': 5,
#   'home-draws': 2,
#   'home-losses': 3,
#   'home-goals': 16,
#   'home-opposition-goals': 15,
#   'home-shots': 145,
#   'home-shots-on-target': 83,
#   'home-opposition-shots': 98,
#   'home-opposition-shots-on-target': 52,
#   'away-wins': 6,
#   'away-draws': 3,
#   'away-losses': 1,
#   'away-goals': 16,
#   'away-opposition-goals': 7,
#   'away-shots': 157,
#   'away-shots-on-target': 73,
#   'away-opposition-shots': 81,
#   'away-opposition-shots-on-target': 40},
#  {'result': 'H',
#   'odds-home': 2.37,
#   'odds-draw': 3.4,
#   'odds-away': 3.0,
#   'home-wins': 3,
#   'home-draws': 5,
#   'home-losses': 2,
#   'home-goals': 15,
#   'home-opposition-goals': 11,
#   'home-shots': 98,
#   'home-shots-on-target': 51,
#   'home-opposition-shots': 146,
#   'home-opposition-shots-on-target': 60,
#   'away-wins': 5,
#   'away-draws': 2,
#   'away-losses': 3,
#   'away-goals': 15,
#   'away-opposition-goals': 11,
#   'away-shots': 126,
#   'away-shots-on-target': 68,
#   'away-opposition-shots': 119,
#   'away-opposition-shots-on-target': 73},
#  {'result': 'H',
#   'odds-home': 3.25,
#   'odds-draw': 3.3,
#   'odds-away': 2.25,
#   'home-wins': 0,
#   'home-draws': 2,
#   'home-losses': 8,
#   'home-goals': 5,
#   'home-opposition-goals': 25,
#   'home-shots': 129,
#   'home-shots-on-target': 60,
#   'home-opposition-shots': 127,
#   'home-opposition-shots-on-target': 82,
#   'away-wins': 2,
#   'away-draws': 3,
#   'away-losses': 5,
#   'away-goals': 12,
#   'away-opposition-goals': 13,
#   'away-shots': 127,
#   'away-shots-on-target': 69,
#   'away-opposition-shots': 111,
#   'away-opposition-shots-on-target': 63},
#  {'result': 'D',
#   'odds-home': 5.0,
#   'odds-draw': 3.6,
#   'odds-away': 1.73,
#   'home-wins': 5,
#   'home-draws': 2,
#   'home-losses': 3,
#   'home-goals': 12,
#   'home-opposition-goals': 10,
#   'home-shots': 105,
#   'home-shots-on-target': 56,
#   'home-opposition-shots': 137,
#   'home-opposition-shots-on-target': 82,
#   'away-wins': 6,
#   'away-draws': 2,
#   'away-losses': 2,
#   'away-goals': 22,
#   'away-opposition-goals': 4,
#   'away-shots': 179,
#   'away-shots-on-target': 101,
#   'away-opposition-shots': 83,
#   'away-opposition-shots-on-target': 37},
#  {'result': 'D',
#   'odds-home': 2.5,
#   'odds-draw': 3.3,
#   'odds-away': 2.87,
#   'home-wins': 6,
#   'home-draws': 2,
#   'home-losses': 2,
#   'home-goals': 18,
#   'home-opposition-goals': 10,
#   'home-shots': 99,
#   'home-shots-on-target': 54,
#   'home-opposition-shots': 120,
#   'home-opposition-shots-on-target': 67,
#   'away-wins': 4,
#   'away-draws': 3,
#   'away-losses': 3,
#   'away-goals': 14,
#   'away-opposition-goals': 15,
#   'away-shots': 129,
#   'away-shots-on-target': 72,
#   'away-opposition-shots': 101,
#   'away-opposition-shots-on-target': 55},
#  {'result': 'H',
#   'odds-home': 1.14,
#   'odds-draw': 7.5,
#   'odds-away': 21.0,
#   'home-wins': 5,
#   'home-draws': 3,
#   'home-losses': 2,
#   'home-goals': 17,
#   'home-opposition-goals': 4,
#   'home-shots': 164,
#   'home-shots-on-target': 89,
#   'home-opposition-shots': 86,
#   'home-opposition-shots-on-target': 41,
#   'away-wins': 1,
#   'away-draws': 2,
#   'away-losses': 7,
#   'away-goals': 7,
#   'away-opposition-goals': 22,
#   'away-shots': 135,
#   'away-shots-on-target': 65,
#   'away-opposition-shots': 120,
#   'away-opposition-shots-on-target': 75},
#  {'result': 'H',
#   'odds-home': 1.33,
#   'odds-draw': 4.5,
#   'odds-away': 12.0,
#   'home-wins': 5,
#   'home-draws': 4,
#   'home-losses': 1,
#   'home-goals': 14,
#   'home-opposition-goals': 6,
#   'home-shots': 150,
#   'home-shots-on-target': 72,
#   'home-opposition-shots': 80,
#   'home-opposition-shots-on-target': 39,
#   'away-wins': 5,
#   'away-draws': 0,
#   'away-losses': 5,
#   'away-goals': 14,
#   'away-opposition-goals': 14,
#   'away-shots': 144,
#   'away-shots-on-target': 79,
#   'away-opposition-shots': 139,
#   'away-opposition-shots-on-target': 72},
#  {'result': 'H',
#   'odds-home': 1.8,
#   'odds-draw': 3.6,
#   'odds-away': 4.5,
#   'home-wins': 2,
#   'home-draws': 2,
#   'home-losses': 6,
#   'home-goals': 11,
#   'home-opposition-goals': 13,
#   'home-shots': 118,
#   'home-shots-on-target': 68,
#   'home-opposition-shots': 117,
#   'home-opposition-shots-on-target': 68,
#   'away-wins': 2,
#   'away-draws': 4,
#   'away-losses': 4,
#   'away-goals': 16,
#   'away-opposition-goals': 20,
#   'away-shots': 123,
#   'away-shots-on-target': 68,
#   'away-opposition-shots': 163,
#   'away-opposition-shots-on-target': 87},
#  {'result': 'A',
#   'odds-home': 2.5,
#   'odds-draw': 3.3,
#   'odds-away': 2.87,
#   'home-wins': 2,
#   'home-draws': 5,
#   'home-losses': 3,
#   'home-goals': 10,
#   'home-opposition-goals': 13,
#   'home-shots': 108,
#   'home-shots-on-target': 50,
#   'home-opposition-shots': 142,
#   'home-opposition-shots-on-target': 78,
#   'away-wins': 5,
#   'away-draws': 3,
#   'away-losses': 2,
#   'away-goals': 11,
#   'away-opposition-goals': 7,
#   'away-shots': 108,
#   'away-shots-on-target': 61,
#   'away-opposition-shots': 121,
#   'away-opposition-shots-on-target': 70},
#  {'result': 'A',
#   'odds-home': 2.2,
#   'odds-draw': 3.25,
#   'odds-away': 3.4,
#   'home-wins': 2,
#   'home-draws': 4,
#   'home-losses': 4,
#   'home-goals': 11,
#   'home-opposition-goals': 15,
#   'home-shots': 117,
#   'home-shots-on-target': 60,
#   'home-opposition-shots': 128,
#   'home-opposition-shots-on-target': 65,
#   'away-wins': 1,
#   'away-draws': 4,
#   'away-losses': 5,
#   'away-goals': 4,
#   'away-opposition-goals': 12,
#   'away-shots': 99,
#   'away-shots-on-target': 57,
#   'away-opposition-shots': 159,
#   'away-opposition-shots-on-target': 85},
#  {'result': 'A',
#   'odds-home': 12.0,
#   'odds-draw': 5.0,
#   'odds-away': 1.3,
#   'home-wins': 3,
#   'home-draws': 4,
#   'home-losses': 3,
#   'home-goals': 7,
#   'home-opposition-goals': 15,
#   'home-shots': 81,
#   'home-shots-on-target': 41,
#   'home-opposition-shots': 125,
#   'home-opposition-shots-on-target': 79,
#   'away-wins': 6,
#   'away-draws': 3,
#   'away-losses': 1,
#   'away-goals': 19,
#   'away-opposition-goals': 6,
#   'away-shots': 181,
#   'away-shots-on-target': 117,
#   'away-opposition-shots': 81,
#   'away-opposition-shots-on-target': 43},
#  {'result': 'D',
#   'odds-home': 2.25,
#   'odds-draw': 3.25,
#   'odds-away': 3.3,
#   'home-wins': 4,
#   'home-draws': 0,
#   'home-losses': 6,
#   'home-goals': 14,
#   'home-opposition-goals': 17,
#   'home-shots': 107,
#   'home-shots-on-target': 52,
#   'home-opposition-shots': 138,
#   'home-opposition-shots-on-target': 75,
#   'away-wins': 1,
#   'away-draws': 2,
#   'away-losses': 7,
#   'away-goals': 12,
#   'away-opposition-goals': 20,
#   'away-shots': 104,
#   'away-shots-on-target': 50,
#   'away-opposition-shots': 115,
#   'away-opposition-shots-on-target': 61},
#  {'result': 'D',
#   'odds-home': 1.72,
#   'odds-draw': 3.6,
#   'odds-away': 5.0,
#   'home-wins': 5,
#   'home-draws': 2,
#   'home-losses': 3,
#   'home-goals': 15,
#   'home-opposition-goals': 11,
#   'home-shots': 126,
#   'home-shots-on-target': 68,
#   'home-opposition-shots': 119,
#   'home-opposition-shots-on-target': 74,
#   'away-wins': 4,
#   'away-draws': 5,
#   'away-losses': 1,
#   'away-goals': 11,
#   'away-opposition-goals': 5,
#   'away-shots': 109,
#   'away-shots-on-target': 67,
#   'away-opposition-shots': 118,
#   'away-opposition-shots-on-target': 53},
#  {'result': 'H',
#   'odds-home': 2.25,
#   'odds-draw': 3.3,
#   'odds-away': 3.25,
#   'home-wins': 4,
#   'home-draws': 2,
#   'home-losses': 4,
#   'home-goals': 12,
#   'home-opposition-goals': 14,
#   'home-shots': 124,
#   'home-shots-on-target': 64,
#   'home-opposition-shots': 114,
#   'home-opposition-shots-on-target': 53,
#   'away-wins': 4,
#   'away-draws': 4,
#   'away-losses': 2,
#   'away-goals': 15,
#   'away-opposition-goals': 10,
#   'away-shots': 99,
#   'away-shots-on-target': 53,
#   'away-opposition-shots': 137,
#   'away-opposition-shots-on-target': 58},
#  {'result': 'H',
#   'odds-home': 1.4,
#   'odds-draw': 4.5,
#   'odds-away': 10.0,
#   'home-wins': 3,
#   'home-draws': 4,
#   'home-losses': 3,
#   'home-goals': 14,
#   'home-opposition-goals': 17,
#   'home-shots': 117,
#   'home-shots-on-target': 68,
#   'home-opposition-shots': 107,
#   'home-opposition-shots-on-target': 61,
#   'away-wins': 2,
#   'away-draws': 3,
#   'away-losses': 5,
#   'away-goals': 11,
#   'away-opposition-goals': 18,
#   'away-shots': 117,
#   'away-shots-on-target': 62,
#   'away-opposition-shots': 135,
#   'away-opposition-shots-on-target': 69},
#  {'result': 'D',
#   'odds-home': 2.62,
#   'odds-draw': 3.3,
#   'odds-away': 2.87,
#   'home-wins': 1,
#   'home-draws': 2,
#   'home-losses': 7,
#   'home-goals': 11,
#   'home-opposition-goals': 19,
#   'home-shots': 98,
#   'home-shots-on-target': 48,
#   'home-opposition-shots': 123,
#   'home-opposition-shots-on-target': 67,
#   'away-wins': 2,
# ...
#   'away-wins': 1,
#   'away-draws': 1,
#   'away-losses': 8,
#   'away-goals': 9,
#   'away-opposition-goals': 24,
#   'away-shots': 100,
#   'away-shots-on-target': 57,
#   'away-opposition-shots': 126,
#   'away-opposition-shots-on-target': 71},
#  {'result': 'H',
#   'odds-home': 2.7,
#   'odds-draw': 3.2,
#   'odds-away': 2.7,
#   'home-wins': 5,
#   'home-draws': 3,
#   'home-losses': 2,
#   'home-goals': 15,
#   'home-opposition-goals': 9,
#   'home-shots': 120,
#   'home-shots-on-target': 70,
#   'home-opposition-shots': 106,
#   'home-opposition-shots-on-target': 64,
#   'away-wins': 5,
#   'away-draws': 2,
#   'away-losses': 3,
#   'away-goals': 16,
#   'away-opposition-goals': 11,
#   'away-shots': 120,
#   'away-shots-on-target': 68,
#   'away-opposition-shots': 123,
#   'away-opposition-shots-on-target': 64},
#  {'result': 'H',
#   'odds-home': 1.91,
#   'odds-draw': 3.4,
#   'odds-away': 4.2,
#   'home-wins': 2,
#   'home-draws': 4,
#   'home-losses': 4,
#   'home-goals': 9,
#   'home-opposition-goals': 13,
#   'home-shots': 110,
#   'home-shots-on-target': 67,
#   'home-opposition-shots': 124,
#   'home-opposition-shots-on-target': 65,
#   'away-wins': 2,
#   'away-draws': 3,
#   'away-losses': 5,
#   'away-goals': 10,
#   'away-opposition-goals': 19,
#   'away-shots': 81,
#   'away-shots-on-target': 41,
#   'away-opposition-shots': 142,
#   'away-opposition-shots-on-target': 82},
#  {'result': 'D',
#   'odds-home': 1.3,
#   'odds-draw': 5.5,
#   'odds-away': 10.0,
#   'home-wins': 3,
#   'home-draws': 5,
#   'home-losses': 2,
#   'home-goals': 17,
#   'home-opposition-goals': 17,
#   'home-shots': 156,
#   'home-shots-on-target': 85,
#   'home-opposition-shots': 119,
#   'home-opposition-shots-on-target': 59,
#   'away-wins': 1,
#   'away-draws': 4,
#   'away-losses': 5,
#   'away-goals': 10,
#   'away-opposition-goals': 21,
#   'away-shots': 111,
#   'away-shots-on-target': 55,
#   'away-opposition-shots': 145,
#   'away-opposition-shots-on-target': 78},
#  {'result': 'D',
#   'odds-home': 1.95,
#   'odds-draw': 3.6,
#   'odds-away': 3.8,
#   'home-wins': 2,
#   'home-draws': 2,
#   'home-losses': 6,
#   'home-goals': 13,
#   'home-opposition-goals': 19,
#   'home-shots': 128,
#   'home-shots-on-target': 74,
#   'home-opposition-shots': 166,
#   'home-opposition-shots-on-target': 96,
#   'away-wins': 1,
#   'away-draws': 4,
#   'away-losses': 5,
#   'away-goals': 10,
#   'away-opposition-goals': 17,
#   'away-shots': 109,
#   'away-shots-on-target': 46,
#   'away-opposition-shots': 126,
#   'away-opposition-shots-on-target': 71},
#  {'result': 'H',
#   'odds-home': 2.38,
#   'odds-draw': 3.25,
#   'odds-away': 3.1,
#   'home-wins': 6,
#   'home-draws': 1,
#   'home-losses': 3,
#   'home-goals': 16,
#   'home-opposition-goals': 9,
#   'home-shots': 147,
#   'home-shots-on-target': 85,
#   'home-opposition-shots': 112,
#   'home-opposition-shots-on-target': 56,
#   'away-wins': 8,
#   'away-draws': 2,
#   'away-losses': 0,
#   'away-goals': 20,
#   'away-opposition-goals': 6,
#   'away-shots': 183,
#   'away-shots-on-target': 104,
#   'away-opposition-shots': 109,
#   'away-opposition-shots-on-target': 58},
#  {'result': 'H',
#   'odds-home': 5.5,
#   'odds-draw': 3.75,
#   'odds-away': 1.67,
#   'home-wins': 2,
#   'home-draws': 4,
#   'home-losses': 4,
#   'home-goals': 12,
#   'home-opposition-goals': 11,
#   'home-shots': 96,
#   'home-shots-on-target': 51,
#   'home-opposition-shots': 116,
#   'home-opposition-shots-on-target': 65,
#   'away-wins': 4,
#   'away-draws': 5,
#   'away-losses': 1,
#   'away-goals': 14,
#   'away-opposition-goals': 9,
#   'away-shots': 144,
#   'away-shots-on-target': 72,
#   'away-opposition-shots': 85,
#   'away-opposition-shots-on-target': 49},
#  {'result': 'H',
#   'odds-home': 2.1,
#   'odds-draw': 3.4,
#   'odds-away': 3.5,
#   'home-wins': 2,
#   'home-draws': 4,
#   'home-losses': 4,
#   'home-goals': 12,
#   'home-opposition-goals': 18,
#   'home-shots': 92,
#   'home-shots-on-target': 44,
#   'home-opposition-shots': 130,
#   'home-opposition-shots-on-target': 68,
#   'away-wins': 4,
#   'away-draws': 5,
#   'away-losses': 1,
#   'away-goals': 20,
#   'away-opposition-goals': 17,
#   'away-shots': 122,
#   'away-shots-on-target': 77,
#   'away-opposition-shots': 126,
#   'away-opposition-shots-on-target': 70},
#  {'result': 'A',
#   'odds-home': 2.88,
#   'odds-draw': 3.25,
#   'odds-away': 2.5,
#   'home-wins': 4,
#   'home-draws': 4,
#   'home-losses': 2,
#   'home-goals': 17,
#   'home-opposition-goals': 10,
#   'home-shots': 130,
#   'home-shots-on-target': 73,
#   'home-opposition-shots': 138,
#   'home-opposition-shots-on-target': 73,
#   'away-wins': 6,
#   'away-draws': 2,
#   'away-losses': 2,
#   'away-goals': 21,
#   'away-opposition-goals': 8,
#   'away-shots': 122,
#   'away-shots-on-target': 70,
#   'away-opposition-shots': 113,
#   'away-opposition-shots-on-target': 58},
#  {'result': 'H',
#   'odds-home': 1.91,
#   'odds-draw': 3.4,
#   'odds-away': 4.2,
#   'home-wins': 5,
#   'home-draws': 1,
#   'home-losses': 4,
#   'home-goals': 15,
#   'home-opposition-goals': 11,
#   'home-shots': 120,
#   'home-shots-on-target': 66,
#   'home-opposition-shots': 119,
#   'home-opposition-shots-on-target': 63,
#   'away-wins': 2,
#   'away-draws': 6,
#   'away-losses': 2,
#   'away-goals': 16,
#   'away-opposition-goals': 17,
#   'away-shots': 163,
#   'away-shots-on-target': 89,
#   'away-opposition-shots': 124,
#   'away-opposition-shots-on-target': 63},
#  {'result': 'D',
#   'odds-home': 5.0,
#   'odds-draw': 3.6,
#   'odds-away': 1.73,
#   'home-wins': 1,
#   'home-draws': 5,
#   'home-losses': 4,
#   'home-goals': 8,
#   'home-opposition-goals': 14,
#   'home-shots': 108,
#   'home-shots-on-target': 45,
#   'home-opposition-shots': 139,
#   'home-opposition-shots-on-target': 79,
#   'away-wins': 6,
#   'away-draws': 1,
#   'away-losses': 3,
#   'away-goals': 16,
#   'away-opposition-goals': 9,
#   'away-shots': 149,
#   'away-shots-on-target': 87,
#   'away-opposition-shots': 118,
#   'away-opposition-shots-on-target': 59},
#  {'result': 'H',
#   'odds-home': 2.2,
#   'odds-draw': 3.4,
#   'odds-away': 3.25,
#   'home-wins': 1,
#   'home-draws': 4,
#   'home-losses': 5,
#   'home-goals': 10,
#   'home-opposition-goals': 21,
#   'home-shots': 110,
#   'home-shots-on-target': 57,
#   'home-opposition-shots': 158,
#   'home-opposition-shots-on-target': 85,
#   'away-wins': 4,
#   'away-draws': 1,
#   'away-losses': 5,
#   'away-goals': 13,
#   'away-opposition-goals': 13,
#   'away-shots': 149,
#   'away-shots-on-target': 82,
#   'away-opposition-shots': 131,
#   'away-opposition-shots-on-target': 66},
#  {'result': 'A',
#   'odds-home': 2.5,
#   'odds-draw': 3.25,
#   'odds-away': 2.88,
#   'home-wins': 2,
#   'home-draws': 1,
#   'home-losses': 7,
#   'home-goals': 9,
#   'home-opposition-goals': 22,
#   'home-shots': 99,
#   'home-shots-on-target': 56,
#   'home-opposition-shots': 125,
#   'home-opposition-shots-on-target': 71,
#   'away-wins': 3,
#   'away-draws': 4,
#   'away-losses': 3,
#   'away-goals': 15,
#   'away-opposition-goals': 17,
#   'away-shots': 104,
#   'away-shots-on-target': 54,
#   'away-opposition-shots': 127,
#   'away-opposition-shots-on-target': 66},
#  {'result': 'H',
#   'odds-home': 2.63,
#   'odds-draw': 3.25,
#   'odds-away': 2.75,
#   'home-wins': 4,
#   'home-draws': 4,
#   'home-losses': 2,
#   'home-goals': 18,
#   'home-opposition-goals': 17,
#   'home-shots': 121,
#   'home-shots-on-target': 72,
#   'home-opposition-shots': 122,
#   'home-opposition-shots-on-target': 69,
#   'away-wins': 6,
#   'away-draws': 3,
#   'away-losses': 1,
#   'away-goals': 17,
#   'away-opposition-goals': 8,
#   'away-shots': 121,
#   'away-shots-on-target': 72,
#   'away-opposition-shots': 107,
#   'away-opposition-shots-on-target': 66},
#  {'result': 'A',
#   'odds-home': 1.36,
#   'odds-draw': 5.0,
#   'odds-away': 8.5,
#   'home-wins': 3,
#   'home-draws': 5,
#   'home-losses': 2,
#   'home-goals': 13,
#   'home-opposition-goals': 12,
#   'home-shots': 141,
#   'home-shots-on-target': 69,
#   'home-opposition-shots': 95,
#   'home-opposition-shots-on-target': 56,
#   'away-wins': 3,
#   'away-draws': 4,
#   'away-losses': 3,
#   'away-goals': 15,
#   'away-opposition-goals': 13,
#   'away-shots': 114,
#   'away-shots-on-target': 63,
#   'away-opposition-shots': 93,
#   'away-opposition-shots-on-target': 50},
#  {'result': 'A',
#   'odds-home': 2.2,
#   'odds-draw': 3.25,
#   'odds-away': 3.4,
#   'home-wins': 2,
#   'home-draws': 3,
#   'home-losses': 5,
#   'home-goals': 11,
#   'home-opposition-goals': 19,
#   'home-shots': 75,
#   'home-shots-on-target': 38,
#   'home-opposition-shots': 151,
#   'home-opposition-shots-on-target': 89,
#   'away-wins': 4,
#   'away-draws': 3,
#   'away-losses': 3,
#   'away-goals': 17,
#   'away-opposition-goals': 13,
#   'away-shots': 127,
#   'away-shots-on-target': 71,
#   'away-opposition-shots': 144,
#   'away-opposition-shots-on-target': 79},
#  {'result': 'D',
#   'odds-home': 1.25,
#   'odds-draw': 6.0,
#   'odds-away': 11.0,
#   'home-wins': 8,
#   'home-draws': 1,
#   'home-losses': 1,
#   'home-goals': 21,
#   'home-opposition-goals': 8,
#   'home-shots': 179,
#   'home-shots-on-target': 106,
#   'home-opposition-shots': 110,
#   'home-opposition-shots-on-target': 58,
#   'away-wins': 3,
#   'away-draws': 3,
#   'away-losses': 4,
#   'away-goals': 11,
#   'away-opposition-goals': 14,
#   'away-shots': 117,
#   'away-shots-on-target': 75,
#   'away-opposition-shots': 125,
#   'away-opposition-shots-on-target': 67},
#  {'result': 'A',
#   'odds-home': 1.73,
#   'odds-draw': 3.8,
#   'odds-away': 4.75,
#   'home-wins': 6,
#   'home-draws': 2,
#   'home-losses': 2,
#   'home-goals': 25,
#   'home-opposition-goals': 10,
#   'home-shots': 131,
#   'home-shots-on-target': 77,
#   'home-opposition-shots': 109,
#   'home-opposition-shots-on-target': 61,
#   'away-wins': 1,
#   'away-draws': 6,
#   'away-losses': 3,
#   'away-goals': 14,
#   'away-opposition-goals': 17,
#   'away-shots': 166,
#   'away-shots-on-target': 91,
#   'away-opposition-shots': 115,
#   'away-opposition-shots-on-target': 57},
#  {'result': 'H',
#   'odds-home': 2.1,
#   'odds-draw': 3.4,
#   'odds-away': 3.5,
#   'home-wins': 2,
#   'home-draws': 4,
#   'home-losses': 4,
#   'home-goals': 10,
#   'home-opposition-goals': 15,
#   'home-shots': 111,
#   'home-shots-on-target': 61,
#   'home-opposition-shots': 110,
#   'home-opposition-shots-on-target': 66,
#   'away-wins': 2,
#   'away-draws': 3,
#   'away-losses': 5,
#   'away-goals': 14,
#   'away-opposition-goals': 19,
#   'away-shots': 136,
#   'away-shots-on-target': 80,
#   'away-opposition-shots': 165,
#   'away-opposition-shots-on-target': 97},
#  {'result': 'H',
#   'odds-home': 1.36,
#   'odds-draw': 4.75,
#   'odds-away': 9.0,
#   'home-wins': 5,
#   'home-draws': 1,
#   'home-losses': 4,
#   'home-goals': 13,
#   'home-opposition-goals': 11,
#   'home-shots': 114,
#   'home-shots-on-target': 61,
#   'home-opposition-shots': 116,
#   'home-opposition-shots-on-target': 61,
#   'away-wins': 3,
#   'away-draws': 4,
#   'away-losses': 3,
#   'away-goals': 15,
#   'away-opposition-goals': 11,
#   'away-shots': 93,
#   'away-shots-on-target': 53,
#   'away-opposition-shots': 120,
#   'away-opposition-shots-on-target': 66},
#  {'result': 'H',
#   'odds-home': 3.2,
#   'odds-draw': 3.4,
#   'odds-away': 2.25,
#   'home-wins': 4,
#   'home-draws': 3,
#   'home-losses': 3,
#   'home-goals': 16,
#   'home-opposition-goals': 13,
#   'home-shots': 115,
#   'home-shots-on-target': 64,
#   'home-opposition-shots': 103,
#   'home-opposition-shots-on-target': 60,
#   'away-wins': 6,
#   'away-draws': 1,
#   'away-losses': 3,
#   'away-goals': 24,
#   'away-opposition-goals': 11,
#   'away-shots': 128,
#   'away-shots-on-target': 74,
#   'away-opposition-shots': 109,
#   'away-opposition-shots-on-target': 63},
#  {'result': 'A',
#   'odds-home': 5.0,
#   'odds-draw': 3.75,
#   'odds-away': 1.7,
#   'home-wins': 3,
#   'home-draws': 1,
#   'home-losses': 6,
#   'home-goals': 14,
#   'home-opposition-goals': 17,
#   'home-shots': 155,
#   'home-shots-on-target': 86,
#   'home-opposition-shots': 134,
#   'home-opposition-shots-on-target': 70,
#   'away-wins': 6,
#   'away-draws': 1,
#   'away-losses': 3,
#   'away-goals': 15,
#   'away-opposition-goals': 9,
#   'away-shots': 117,
#   'away-shots-on-target': 62,
#   'away-opposition-shots': 109,
#   'away-opposition-shots-on-target': 57},
#  {'result': 'H',
#   'odds-home': 3.1,
#   'odds-draw': 3.25,
#   'odds-away': 2.38,
#   'home-wins': 5,
#   'home-draws': 3,
#   'home-losses': 2,
#   'home-goals': 15,
#   'home-opposition-goals': 9,
#   'home-shots': 127,
#   'home-shots-on-target': 73,
#   'home-opposition-shots': 109,
#   'home-opposition-shots-on-target': 68,
#   'away-wins': 7,
#   'away-draws': 2,
#   'away-losses': 1,
#   'away-goals': 21,
#   'away-opposition-goals': 9,
#   'away-shots': 177,
#   'away-shots-on-target': 102,
#   'away-opposition-shots': 111,
#   'away-opposition-shots-on-target': 60},
#  {'result': 'D',
#   'odds-home': 3.75,
#   'odds-draw': 3.6,
#   'odds-away': 1.95,
#   'home-wins': 5,
#   'home-draws': 2,
#   'home-losses': 3,
#   'home-goals': 19,
#   'home-opposition-goals': 13,
#   'home-shots': 133,
#   'home-shots-on-target': 72,
#   'home-opposition-shots': 128,
#   'home-opposition-shots-on-target': 72,
#   'away-wins': 2,
#   'away-draws': 5,
#   'away-losses': 3,
#   'away-goals': 13,
#   'away-opposition-goals': 14,
#   'away-shots': 156,
#   'away-shots-on-target': 80,
#   'away-opposition-shots': 96,
#   'away-opposition-shots-on-target': 57},
#  {'result': 'H',
#   'odds-home': 1.6,
#   'odds-draw': 4.0,
#   'odds-away': 5.5,
#   'home-wins': 5,
#   'home-draws': 2,
#   'home-losses': 3,
#   'home-goals': 13,
#   'home-opposition-goals': 10,
#   'home-shots': 144,
#   'home-shots-on-target': 82,
#   'home-opposition-shots': 114,
#   'home-opposition-shots-on-target': 57,
#   'away-wins': 1,
#   'away-draws': 4,
#   'away-losses': 5,
#   'away-goals': 11,
#   'away-opposition-goals': 23,
#   'away-shots': 114,
#   'away-shots-on-target': 61,
#   'away-opposition-shots': 150,
#   'away-opposition-shots-on-target': 84},
#  {'result': 'D',
#   'odds-home': 2.0,
#   'odds-draw': 3.5,
#   'odds-away': 3.75,
#   'home-wins': 2,
#   'home-draws': 4,
#   'home-losses': 4,
#   'home-goals': 11,
#   'home-opposition-goals': 16,
#   'home-shots': 120,
#   'home-shots-on-target': 77,
#   'home-opposition-shots': 129,
#   'home-opposition-shots-on-target': 69,
#   'away-wins': 5,
#   'away-draws': 3,
#   'away-losses': 2,
#   'away-goals': 18,
#   'away-opposition-goals': 16,
#   'away-shots': 116,
#   'away-shots-on-target': 70,
#   'away-opposition-shots': 139,
#   'away-opposition-shots-on-target': 77},
#  {'result': 'A',
#   'odds-home': 2.75,
#   'odds-draw': 3.6,
#   'odds-away': 2.4,
#   'home-wins': 3,
#   'home-draws': 4,
#   'home-losses': 3,
#   'home-goals': 15,
#   'home-opposition-goals': 13,
#   'home-shots': 90,
#   'home-shots-on-target': 51,
#   'home-opposition-shots': 127,
#   'home-opposition-shots-on-target': 71,
#   'away-wins': 3,
#   'away-draws': 3,
#   'away-losses': 4,
#   'away-goals': 12,
#   'away-opposition-goals': 16,
#   'away-shots': 122,
#   'away-shots-on-target': 69,
#   'away-opposition-shots': 110,
#   'away-opposition-shots-on-target': 71},
#  {'result': 'H',
#   'odds-home': 1.53,
#   'odds-draw': 4.0,
#   'odds-away': 6.5,
#   'home-wins': 2,
#   'home-draws': 6,
#   'home-losses': 2,
#   'home-goals': 15,
#   'home-opposition-goals': 14,
#   'home-shots': 149,
#   'home-shots-on-target': 85,
#   'home-opposition-shots': 117,
#   'home-opposition-shots-on-target': 55,
#   'away-wins': 2,
#   'away-draws': 3,
#   'away-losses': 5,
#   'away-goals': 10,
#   'away-opposition-goals': 18,
#   'away-shots': 73,
#   'away-shots-on-target': 36,
#   'away-opposition-shots': 160,
#   'away-opposition-shots-on-target': 93},
#  {'result': 'A',
#   'odds-home': 2.0,
#   'odds-draw': 3.5,
#   'odds-away': 3.75,
#   'home-wins': 2,
#   'home-draws': 2,
#   'home-losses': 6,
#   'home-goals': 13,
#   'home-opposition-goals': 19,
#   'home-shots': 131,
#   'home-shots-on-target': 79,
#   'home-opposition-shots': 169,
#   'home-opposition-shots-on-target': 96,
#   'away-wins': 2,
#   'away-draws': 1,
#   'away-losses': 7,
#   'away-goals': 9,
#   'away-opposition-goals': 23,
#   'away-shots': 97,
#   'away-shots-on-target': 55,
#   'away-opposition-shots': 124,
#   'away-opposition-shots-on-target': 72},
#  {'result': 'A',
#   'odds-home': 2.2,
#   'odds-draw': 3.0,
#   'odds-away': 3.75,
#   'home-wins': 4,
#   'home-draws': 3,
#   'home-losses': 3,
#   'home-goals': 17,
#   'home-opposition-goals': 17,
#   'home-shots': 108,
#   'home-shots-on-target': 58,
#   'home-opposition-shots': 122,
#   'home-opposition-shots-on-target': 64,
#   'away-wins': 1,
#   'away-draws': 5,
#   'away-losses': 4,
#   'away-goals': 9,
#   'away-opposition-goals': 15,
#   'away-shots': 110,
#   'away-shots-on-target': 47,
#   'away-opposition-shots': 136,
#   'away-opposition-shots-on-target': 77},
#  ...]

# %%
#with open("data/out.csv","r+") as fout:
    

fout=open("data/out.csv","a")
# first file:
for line in open("data/00.csv"):
    fout.write(line)
# now the rest:    
for num in range(1,18):
    f = open('data/' + str(num).zfill(2)+".csv", 'r+')
    next(f) # skip the header
    for line in f:
         fout.write(line)
    f.close() # not really needed
fout.close()

# %%
import os

csv_header = 'Timestamp,Client IP,Web Service,Status,Good,Bad'
csv_out = 'data/consolidated.csv'

csv_dir = os.getcwd()

dir_tree = os.walk(csv_dir)
for dirpath, dirnames, filenames in dir_tree:
    pass

csv_list = []
for file in filenames:
    if file.endswith('.csv'):
        csv_list.append(file)

csv_merge = open(csv_out, 'w')
csv_merge.write(csv_header)
csv_merge.write('\n')

for file in csv_list:
    csv_in = open(file)
    for line in csv_in:
        if line.startswith(csv_header):
            continue
        csv_merge.write(line)
    csv_in.close()
    csv_merge.close()
print('Verify consolidated CSV file : ' + csv_out)
# Out:
# Verify consolidated CSV file : consolidated.csv
